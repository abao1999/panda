# %%
import dysts.flows as flows
import numpy as np
import matplotlib.pyplot as plt

# %%
sys = flows.Lorenz()
sol = sys.make_trajectory(1000, standardize=True)

# %%
combs = np.random.dirichlet(0.6*np.ones(3), size=100)
rand_combs = combs@sol.T

#mu, std = rand_combs.mean(-2), rand_combs.std(-2)
#rand_combs -= mu
#rand_combs /= std

plt.figure(figsize=(10,3))
#for ts in sol.T:
#    plt.plot(ts)
for ts in rand_combs:
    plt.plot(ts, lw=0.5)
